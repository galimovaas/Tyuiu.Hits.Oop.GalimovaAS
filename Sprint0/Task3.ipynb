# %% [markdown]
# <h1 style="color:DodgerBlue">Индивидальный проект</h1>

# %% [markdown]
# <h2 style="color:DodgerBlue">Название проекта:</h2>
#
# ----
#
# ### Вариант задания
# №4

# %% [markdown]
# <h2 style="color:DodgerBlue">Описание проекта:</h2>
#
# ----
#
# Создать базовый класс Product в C#, который будет представлять информацию о
# продуктах. На основе этого класса разработать 2-3 производных класса,
# демонстрирующих принципы наследования и полиморфизма. В каждом из классов
# должны быть реализованы новые атрибуты и методы, а также переопределены
# некоторые методы базового класса для демонстрации полиморфизма.

# %% [markdown]
# <h2 style="color:DodgerBlue">Реализация:</h2>
#
# ----

# %%
using System;

public class Product
{
    public string Name { get; set; }
    public decimal Price { get; set; }
    public string Manufacturer { get; set; }

    public Product(string name, decimal price, string manufacturer)
    {
        Name = name;
        Price = price;
        Manufacturer = manufacturer;
    }

    public virtual string GetInfo()
    {
        return $"Название: {Name}, Цена: {Price:C}, Производитель: {Manufacturer}";
    }

    public virtual void ApplyDiscount(decimal discountPercentage)
    {
        if (discountPercentage >= 0 && discountPercentage <= 100)
        {
            Price -= Price * (discountPercentage / 100);
        }
    }

    public virtual void Display()
    {
        Console.WriteLine(GetInfo());
    }
}

public class Electronics : Product
{
    public int WarrantyPeriod { get; set; }

    public Electronics(string name, decimal price, string manufacturer, int warrantyPeriod)
        : base(name, price, manufacturer)
    {
        WarrantyPeriod = warrantyPeriod;
    }

    public override void ApplyDiscount(decimal discountPercentage)
    {
        if (WarrantyPeriod > 12) 
        {
            discountPercentage += 5;
            Console.WriteLine($"Дополнительная 5% скидка за extended гарантию!");
        }
        
        base.ApplyDiscount(discountPercentage);
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Гарантия: {WarrantyPeriod} месяцев";
    }
}

public class Clothing : Product
{
    public string Size { get; set; }

    public Clothing(string name, decimal price, string manufacturer, string size)
        : base(name, price, manufacturer)
    {
        Size = size;
    }

    public override void Display()
    {
        Console.WriteLine($"Одежда: {Name}, Размер: {Size}, Цена: {Price:C}, Производитель: {Manufacturer}");
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Размер: {Size}";
    }
}

public class Books : Product
{
    public string Author { get; set; }

    public Books(string name, decimal price, string manufacturer, string author)
        : base(name, price, manufacturer)
    {
        Author = author;
    }

    public override string GetInfo()
    {
        return $"Книга: {Name}, Автор: {Author}, Цена: {Price:C}, Издательство: {Manufacturer}";
    }
}

Console.WriteLine("Демонстрация принципов наследования и полиморфизма:");
Console.WriteLine("===================================================");


Electronics smartphone = new Electronics("Смартфон", 50000, "Samsung", 24);
Clothing tshirt = new Clothing("Футболка", 1500, "Nike", "L");
Books book = new Books("Война и мир", 1200, "Эксмо", "Лев Толстой");
Electronics laptop = new Electronics("Ноутбук", 80000, "Apple", 12);

Product[] products = new Product[] { smartphone, tshirt, book, laptop };

foreach (var product in products)
{
    Console.WriteLine("\nДо скидки:");
    product.Display();
    
    product.ApplyDiscount(10);
    
    Console.WriteLine("После 10% скидки:");
    product.Display();
    Console.WriteLine("-------------------");
}

Console.WriteLine("\n=== Простые действия с продуктами ===\n");


Electronics myElectronics = new Electronics("Наушники", 2500, "Sony", 24);
Clothing myClothing = new Clothing("Джинсы", 3500, "Levi's", "32");
Books myBooks = new Books("Мастер и Маргарита", 950, "Азбука", "Михаил Булгаков");

Console.WriteLine("Электроника:");
myElectronics.ApplyDiscount(10);
Console.WriteLine(myElectronics.GetInfo());
Console.WriteLine();

Console.WriteLine("Одежда:");
myClothing.ApplyDiscount(15);
myClothing.Display();
Console.WriteLine();

Console.WriteLine("Книги:");
myBooks.ApplyDiscount(20);
Console.WriteLine(myBooks.GetInfo());
# Out:
# Демонстрация принципов наследования и полиморфизма:
# ===================================================
#
# До скидки:
# Название: Смартфон, Цена: ¤50,000.00, Производитель: Samsung, Гарантия: 24 месяцев
# Дополнительная 5% скидка за extended гарантию!
# После 10% скидки:
# Название: Смартфон, Цена: ¤42,500.00, Производитель: Samsung, Гарантия: 24 месяцев
# -------------------
#
# До скидки:
# Одежда: Футболка, Размер: L, Цена: ¤1,500.00, Производитель: Nike
# После 10% скидки:
# Одежда: Футболка, Размер: L, Цена: ¤1,350.00, Производитель: Nike
# -------------------
#
# До скидки:
# Книга: Война и мир, Автор: Лев Толстой, Цена: ¤1,200.00, Издательство: Эксмо
# После 10% скидки:
# Книга: Война и мир, Автор: Лев Толстой, Цена: ¤1,080.00, Издательство: Эксмо
# -------------------
#
# До скидки:
# Название: Ноутбук, Цена: ¤80,000.00, Производитель: Apple, Гарантия: 12 месяцев
# После 10% скидки:
# Название: Ноутбук, Цена: ¤72,000.00, Производитель: Apple, Гарантия: 12 месяцев
# -------------------
#
# === Простые действия с продуктами ===
#
# Электроника:
# Дополнительная 5% скидка за extended гарантию!
# Название: Наушники, Цена: ¤2,125.00, Производитель: Sony, Гарантия: 24 месяцев
#
# Одежда:
# Одежда: Джинсы, Размер: 32, Цена: ¤2,975.00, Производитель: Levi's
#
# Книги:
# Книга: Мастер и Маргарита, Автор: Михаил Булгаков, Цена: ¤760.00, Издательство: Азбука
