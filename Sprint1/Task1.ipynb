// %% [markdown]
// <h1 style="color:DodgerBlue">Структура и объявление класса, через: свойства, геттеры и сеттеры</h1>

// %% [markdown]
// ### Структура и Объявление Класса в C#
//
// В C#, класс объявляется с использованием ключевого слова `class`, за которым следует имя класса. Класс может содержать поля (данные), свойства (способ доступа к данным), методы (функциональность) и события.
//
// #### Свойства
//
// Свойства в C# используются для инкапсуляции данных. Они предоставляют гибкий механизм для чтения, записи или вычисления значений приватных полей. Свойства могут иметь два акцессора: `get` (геттер) для чтения значения и `set` (сеттер) для его изменения.
//
// #### Геттеры и Сеттеры
//
// Геттеры и сеттеры являются частью свойств класса в C#. Геттер (`get`) используется для возврата значения свойства, а сеттер (`set`) — для установки нового значения. Сеттер может включать логику валидации или другие операции перед изменением значения поля.
//
// ### Пример Классов Vehicle и Car
//
// Давайте рассмотрим примеры классов `Vehicle` и `Car`, чтобы проиллюстрировать использование свойств, геттеров и сеттеров, а также разницу между статическими и обычными атрибутами и методами.
//
// #### Класс Vehicle
//
// ```csharp
// public class Vehicle
// {
//     private string _color;
//     private int _speed;
//
//     // Свойство Color с геттером и сеттером
//     public string Color
//     {
//         get { return _color; }
//         set { _color = value; }
//     }
//
//     // Свойство Speed с геттером и сеттером
//     public int Speed
//     {
//         get { return _speed; }
//         set
//         {
//             if (value >= 0)
//                 _speed = value;
//             else
//                 throw new ArgumentOutOfRangeException("Скорость не может быть отрицательной!");
//         }
//     }
//
//     // Статический атрибут
//     public static int TotalVehicles { get; private set; } = 0;
//
//     // Конструктор
//     public Vehicle()
//     {
//         TotalVehicles++;
//     }
//
//     // Обычный метод
//     public void Accelerate(int delta)
//     {
//         Speed += delta;
//     }
//
//     // Статический метод
//     public static void DisplayTotalVehicles()
//     {
//         Console.WriteLine($"Общее количество транспортных средств: {TotalVehicles}");
//     }
// }
// ```
//
// #### Класс Car
//
// ```csharp
// public class Car : Vehicle
// {
//     private int _fuelLevel;
//
//     // Свойство FuelLevel с геттером и сеттером
//     public int FuelLevel
//     {
//         get { return _fuelLevel; }
//         set { _fuelLevel = value; }
//     }
//
//     // Конструктор
//     public Car() : base()
//     {
//         FuelLevel = 100; // Задаем начальный уровень топлива
//     }
//
//     // Обычный метод
//     public void Refuel(int amount)
//     {
//         FuelLevel += amount;
//     }
// }
// ```
//
// ### Разница между Статическими и Обычными Атрибутами и Методами Класса
//
// - **Статические атрибуты и методы** принадлежат самому классу, а не его экземплярам. Они могут быть вызваны без создания объекта класса. В примере выше `TotalVehicles` является статическим атрибутом, а `DisplayTotalVehicles()` — статическим методом класса `Vehicle`.
// - **Обычные атрибуты и методы** принадлежат экземплярам класса и могут иметь разные значения для разных объектов. В примере выше `_color`, `_speed` и `_fuelLevel` являются обычными атрибутами, а методы `Accelerate()` и `Refuel()` — обычными методами.
//
// ### Заключение
//
// В этом таске мы рассмотрели структуру и объявление класса в C#, включая свойства, геттеры и сеттеры, а также разницу между статическими и обычными атрибутами и методами класса на примерах классов `Vehicle` и `Car`. Эти концепции являются основой для создания объектно-ориентированных программ на C#.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Car и Vehicle ниже в блоке:</h4>
//
// ----

// %%
public class Vehicle
{
    private string _color;
    private int _speed;

    public string Color
    {
        get { return _color; }
        set { _color = value; }
    }

    public int Speed
    {
        get { return _speed; }
        set
        {
            if (value >= 0)
                _speed = value;
            else
                throw new ArgumentOutOfRangeException("Скорость не может быть отрицательной!");
        }
    }

    public static int TotalVehicles { get; private set; } = 0;

    public Vehicle()
    {
        TotalVehicles++;
    }

    public void Accelerate(int delta)
    {
        Speed += delta;
    }

    public static void DisplayTotalVehicles()
    {
        Console.WriteLine($"Общее количество транспортных средств: {TotalVehicles}");
    }
}
public class Car : Vehicle
{
    private int _fuelLevel;

    public int FuelLevel
    {
        get { return _fuelLevel; }
        set { _fuelLevel = value; }
    }


    public Car() : base()
    {
        FuelLevel = 100; 
    }


    public void Refuel(int amount)
    {
        FuelLevel += amount;
    }
}
        Car myCar = new Car();
        myCar.Color = "Черный";
        myCar.Accelerate(70);
        myCar.Refuel(20);

        Console.WriteLine($"Машина цвета {myCar.Color} едет со скоростью {myCar.Speed} км/ч");
        Console.WriteLine($"Уровень топлива: {myCar.FuelLevel} л");
        
        Vehicle.DisplayTotalVehicles();
// Out:
// Машина цвета Черный едет со скоростью 70 км/ч
// Уровень топлива: 120 л
// Общее количество транспортных средств: 1

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (2-3 например Dog, Cat и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также статические и обычными атрибуты и метода класса

// %%
using System;

public class Animal
{
    private string _species;
    private int _age;
    private double _weight;

    public static int TotalAnimals { get; private set; } = 0;

    public string Species
    {
        get { return _species; }
        set
        {
            if (!string.IsNullOrWhiteSpace(value))
                _species = value;
            else
                throw new ArgumentException("Вид животного не может быть пустым!");
        }
    }

    public int Age
    {
        get { return _age; }
        set
        {
            if (value >= 0)
                _age = value;
            else
                throw new ArgumentOutOfRangeException("Возраст не может быть отрицательным!");
        }
    }

    public double Weight
    {
        get { return _weight; }
        set
        {
            if (value > 0)
                _weight = value;
            else
                throw new ArgumentOutOfRangeException("Вес должен быть положительным!");
        }
    }

    public Animal()
    {
        TotalAnimals++;
        Species = "Неизвестный вид";
        Age = 0;
        Weight = 1.0;
    }

    public Animal(string species, int age, double weight) : this()
    {
        Species = species;
        Age = age;
        Weight = weight;
    }

    public virtual void MakeSound()
    {
        Console.WriteLine($"{Species} издает звук");
    }

    public void Eat(double foodAmount)
    {
        if (foodAmount > 0)
        {
            Weight += foodAmount * 0.1;
            Console.WriteLine($"{Species} поел и теперь весит {Weight} кг");
        }
    }

    public static void DisplayTotalAnimals()
    {
        Console.WriteLine($"Всего животных создано: {TotalAnimals}");
    }

    public override string ToString()
    {
        return $"Вид: {Species}, Возраст: {Age} лет, Вес: {Weight} кг";
    }
}

public class Dog : Animal
{
    private string _breed;
    private bool _isTrained;

    public string Breed
    {
        get { return _breed; }
        set { _breed = value; }
    }

    public bool IsTrained
    {
        get { return _isTrained; }
        set { _isTrained = value; }
    }

    public Dog() : base("Собака", 1, 10.0)
    {
        Breed = "Дворняжка";
        IsTrained = false;
    }

    public Dog(string breed, int age, double weight, bool isTrained) 
        : base("Собака", age, weight)
    {
        Breed = breed;
        IsTrained = isTrained;
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Breed} гавкает: Гав-гав!");
    }

    public void Fetch()
    {
        Console.WriteLine($"{Breed} принес палку!");
    }

    public void Train()
    {
        if (!IsTrained)
        {
            IsTrained = true;
            Console.WriteLine($"{Breed} прошел обучение!");
        }
        else
        {
            Console.WriteLine($"{Breed} уже обучен!");
        }
    }

    public override string ToString()
    {
        string trainedStatus = IsTrained ? "обучена" : "не обучена";
        return base.ToString() + $", Порода: {Breed}, {trainedStatus}";
    }
}

public class Cat : Animal
{
    private int _lives;
    private bool _isLazy;

    public int Lives
    {
        get { return _lives; }
        set
        {
            if (value >= 0 && value <= 9)
                _lives = value;
            else
                throw new ArgumentOutOfRangeException("У кошки может быть от 0 до 9 жизней!");
        }
    }

    public bool IsLazy
    {
        get { return _isLazy; }
        set { _isLazy = value; }
    }

    public Cat() : base("Кошка", 1, 4.0)
    {
        Lives = 9;
        IsLazy = true;
    }

    public Cat(int age, double weight, int lives, bool isLazy) 
        : base("Кошка", age, weight)
    {
        Lives = lives;
        IsLazy = isLazy;
    }

    public override void MakeSound()
    {
        Console.WriteLine("Мяу-мяу");
    }

    public void Purr()
    {
        Console.WriteLine($"{Species} мурлычет: Мррррр...");
    }

    public void Sleep()
    {
        if (IsLazy)
        {
            Console.WriteLine($"{Species} сладко спит целый день... zZz");
        }
        else
        {
            Console.WriteLine($"{Species} немного поспала и проснулась");
        }
    }

    public override string ToString()
    {
        string lazyStatus = IsLazy ? "ленивая" : "активная";
        return base.ToString() + $", Жизней: {Lives}, {lazyStatus}";
    }
}

public class Bird : Animal
{
    private double _wingspan;
    private bool _canFly;

    public double Wingspan
    {
        get { return _wingspan; }
        set
        {
            if (value > 0)
                _wingspan = value;
            else
                throw new ArgumentOutOfRangeException("Размах крыльев должен быть положительным!");
        }
    }

    public bool CanFly
    {
        get { return _canFly; }
        set { _canFly = value; }
    }

    public Bird() : base("Птица", 1, 0.5)
    {
        Wingspan = 0.3;
        CanFly = true;
    }

    public Bird(string species, int age, double weight, double wingspan, bool canFly) 
        : base(species, age, weight)
    {
        Wingspan = wingspan;
        CanFly = canFly;
    }

    public override void MakeSound()
    {
        Console.WriteLine("Чик-чирик!");
    }

    public void Fly()
    {
        if (CanFly)
        {
            Console.WriteLine($"{Species} летит с размахом крыльев {Wingspan} м!");
        }
        else
        {
            Console.WriteLine($"{Species} не умеет летать!");
        }
    }

    public void BuildNest()
    {
        Console.WriteLine($"{Species} строит гнездо!");
    }

    public override string ToString()
    {
        string flyAbility = CanFly ? "умеет летать" : "не летает";
        return base.ToString() + $", Размах крыльев: {Wingspan} м, {flyAbility}";
    }
}


 Console.WriteLine("=== Демонстрация системы животных ===\n");

        Dog myDog = new Dog("Лабрадор", 3, 25.5, false);
        Cat myCat = new Cat(2, 3.8, 8, true);
        Bird myBird = new Bird("Попугай", 1, 0.3, 0.4, true);

        Console.WriteLine("=== Информация о животных ===");
        Console.WriteLine(myDog);
        Console.WriteLine(myCat);
        Console.WriteLine(myBird);
        Console.WriteLine();

        Console.WriteLine("=== Звуки животных ===");
        myDog.MakeSound();
        myCat.MakeSound();
        myBird.MakeSound();
        Console.WriteLine();

        Console.WriteLine("=== Особые способности ===");
        myDog.Fetch();
        myDog.Train();
        myCat.Purr();
        myCat.Sleep();
        myBird.Fly();
        myBird.BuildNest();
        Console.WriteLine();

        Console.WriteLine("=== Кормление животных ===");
        myDog.Eat(1.0);
        myCat.Eat(0.3);
        myBird.Eat(0.1);
        Console.WriteLine();

        Animal.DisplayTotalAnimals();
// Out:
// === Демонстрация системы животных ===
//
// === Информация о животных ===
// Вид: Собака, Возраст: 3 лет, Вес: 25.5 кг, Порода: Лабрадор, не обучена
// Вид: Кошка, Возраст: 2 лет, Вес: 3.8 кг, Жизней: 8, ленивая
// Вид: Попугай, Возраст: 1 лет, Вес: 0.3 кг, Размах крыльев: 0.4 м, умеет летать
//
// === Звуки животных ===
// Лабрадор гавкает: Гав-гав!
// Мяу-мяу
// Чик-чирик!
//
// === Особые способности ===
// Лабрадор принес палку!
// Лабрадор прошел обучение!
// Кошка мурлычет: Мррррр...
// Кошка сладко спит целый день... zZz
// Попугай летит с размахом крыльев 0.4 м!
// Попугай строит гнездо!
//
// === Кормление животных ===
// Собака поел и теперь весит 25.6 кг
// Кошка поел и теперь весит 3.8299999999999996 кг
// Попугай поел и теперь весит 0.31 кг
//
// Всего животных создано: 3
